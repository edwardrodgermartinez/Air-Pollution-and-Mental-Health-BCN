# %%
import pandas as pd
import numpy as np
import pymysql
import sqlalchemy as alch
import os
from dotenv import load_dotenv
from getpass import getpass

# %%
pwd
# Out:
# '/Users/edwardrodger/Documents/BARCELONA_22-3/IRONHACK/Course/projects/project_4/edu_project_IV'

# %%
BCN_DATA = pd.read_csv("data/BCN_DATA.csv")

# %%
BCN_DATA.columns.tolist()
# Out:
# ['ID_Zenodo',
#  'date_all',
#  'year',
#  'month',
#  'day',
#  'dayoftheweek',
#  'hour',
#  'mentalhealth_survey',
#  'occurrence_mental',
#  'bienestar',
#  'energia',
#  'estres',
#  'sueno',
#  'horasfuera',
#  'actividadfisica',
#  'ordenador',
#  'dieta',
#  'alcohol',
#  'drogas',
#  'bebida',
#  'enfermo',
#  'otrofactor',
#  'stroop_test',
#  'occurrence_stroop',
#  'mean_incongruent',
#  'correct',
#  'response_duration_ms',
#  'performance',
#  'mean_congruent',
#  'inhib_control',
#  'z_performance',
#  'z_mean_incongruent',
#  'z_inhib_control',
#  'no2bcn_24h',
#  'no2bcn_12h',
#  'no2gps_24h',
#  'no2gps_12h',
#  'no2bcn_12h_x30',
#  'no2bcn_24h_x30',
#  'no2gps_12h_x30',
#  'no2gps_24h_x30',
#  'min_gps',
#  'hour_gps',
#  'pm25bcn',
#  'BCμg',
#  'sec_noise55_day',
#  'sec_noise65_day',
#  'sec_greenblue_day',
#  'hours_noise_55_day',
#  'hours_noise_65_day',
#  'hours_greenblue_day',
#  'tmean_24h',
#  'tmean_12h',
#  'humi_24h',
#  'humi_12h',
#  'pressure_24h',
#  'pressure_12h',
#  'precip_24h',
#  'precip_12h',
#  'precip_12h_binary',
#  'precip_24h_binary',
#  'maxwindspeed_24h',
#  'maxwindspeed_12h',
#  'noise_total_LDEN_55',
#  'access_greenbluespaces_300mbuff',
#  'µgm3',
#  'incidence_cat',
#  'start_day',
#  'start_month',
#  'start_year',
#  'start_hour',
#  'end_day',
#  'end_month',
#  'end_year',
#  'end_hour',
#  'Totaltime',
#  'Totaltime_estimated',
#  'Houron',
#  'Houroff',
#  'age_yrs',
#  'yearbirth',
#  'smoke',
#  'psycho',
#  'gender',
#  'district',
#  'education',
#  'covid_work',
#  'covid_mood',
#  'covid_sleep',
#  'covid_espacios',
#  'covid_aire',
#  'covid_motor',
#  'covid_electric',
#  'covid_bikewalk',
#  'covid_public_trans']

# %%
columns_to_keep = ['occurrence_mental', 'bienestar', 'estres', 'sueno', 'horasfuera', 'enfermo', 'performance', 'z_performance', 'µgm3', 'district', 'sec_noise55_day', 'hours_greenblue_day', 'access_greenbluespaces_300mbuff', 'age_yrs', 'gender']

# %%
BCN_DATA_F = BCN_DATA[columns_to_keep]

# %%
BCN_DATA_F
# Out:
#       occurrence_mental  bienestar  estres  sueno  horasfuera enfermo  \
# 0                   1.0        9.0     1.0   10.0         7.0      No
# 1                   2.0        8.0     5.0    8.0         5.0      No
# 2                  10.0        9.0     8.0    9.0         8.0     Yes
# 3                  14.0        3.0     5.0    2.0         5.0      No
# 4                  12.0        9.0     6.0    2.0        22.0      No
# ...                 ...        ...     ...    ...         ...     ...
# 3343                3.0        8.0     1.0    9.0         2.0      No
# 3344                NaN        NaN     NaN    NaN         NaN     NaN
# 3345                7.0        7.0     2.0    5.0         4.0      No
# 3346               10.0        8.0     5.0    8.0        12.0      No
# 3347                8.0        9.0     2.0    7.0         7.0      No
#
#       performance  z_performance   µgm3        district  sec_noise55_day  \
# 0             NaN            NaN    NaN  Horta-Guinardo           6602.0
# 1       51.240993       0.817020  19.66          Gràcia              NaN
# 2       56.006067       0.541222  28.48        Eixample              NaN
# 3       58.177117       0.749152  15.72      Sant Martí              0.0
# 4       71.481757       2.112378  26.66  Sants-Montjuïc              NaN
# ...           ...            ...    ...             ...              ...
# 3343    43.662164      -0.159908  25.88      Sant Martí          33323.0
# 3344    50.462574      -0.008353  27.68     Sant Andreu            759.0
# 3345    47.614324      -0.028027  25.88      Sant Martí           2998.0
# 3346    60.678845       1.004475  22.03          Gràcia              8.0
# 3347    44.510386      -0.447910  25.88      Sant Martí              6.0
#
#       hours_greenblue_day access_greenbluespaces_300mbuff  age_yrs  gender
# 0                1.918611                             NaN     49.0   Mujer
# 1                     NaN                             Yes     37.0   Mujer
# 2                     NaN                             Yes     28.0   Mujer
# 3                0.000000                             Yes     29.0   Mujer
# 4                     NaN                             Yes     33.0   Mujer
# ...                   ...                             ...      ...     ...
# 3343             0.169444                             NaN     53.0   Mujer
# 3344             0.390833                             Yes     39.0   Mujer
# 3345             0.000556                             NaN     53.0   Mujer
# 3346             0.000000                              No     29.0  Hombre
# 3347             0.000000                             NaN     53.0   Mujer
#
# [3348 rows x 15 columns]

# %%
BCN_DF = BCN_DATA_F

# %%
BCN_DF["district"].value_counts()
# Out:
# district
# Sant Martí             681
# Eixample               599
# Gràcia                 513
# Sants-Montjuïc         282
# Sant Andreu            250
# Ciutat Vella           234
# Horta-Guinardo         208
# Sarria Sant-Gervasi    177
# Nou Barris             107
# 16                      67
# Les Corts               65
# Name: count, dtype: int64

# %%
for i in BCN_DF["district"]:
    if i == 'Horta-Guinardo': 
        BCN_DF.loc[BCN_DF["district"] == i, "district_mean_salary"] = 29223
    elif i == 'Gràcia':
        BCN_DF.loc[BCN_DF["district"] == i, "district_mean_salary"] = 33577
    elif i == 'Eixample':
        BCN_DF.loc[BCN_DF["district"] == i, "district_mean_salary"] = 34770
    elif i == 'Sant Martí':
        BCN_DF.loc[BCN_DF["district"] == i, "district_mean_salary"] = 30648
    elif i == 'Sants-Montjuïc':
        BCN_DF.loc[BCN_DF["district"] == i, "district_mean_salary"] = 27350
    elif i == 'Sant Andreu':
        BCN_DF.loc[BCN_DF["district"] == i, "district_mean_salary"] = 27877
    elif i == 'Sarria Sant-Gervasi':
        BCN_DF.loc[BCN_DF["district"] == i, "district_mean_salary"] = 49196
    elif i == 'Nou Barris':
        BCN_DF.loc[BCN_DF["district"] == i, "district_mean_salary"] = 22844
    elif i == 'Les Corts':
        BCN_DF.loc[BCN_DF["district"] == i, "district_mean_salary"] = 41548
    elif i == 'Ciutat Vella':
        BCN_DF.loc[BCN_DF["district"] == i, "district_mean_salary"] = 22529
    else:
        BCN_DF.loc[BCN_DF["district"] == i, "district_mean_salary"] = None
# Out:
# /var/folders/q9/jkycd7cd6tqdf410bnlz4q2c0000gn/T/ipykernel_1410/3179208085.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BCN_DF.loc[BCN_DF["district"] == i, "district_mean_salary"] = 29223

# %%
BCN_DF.sample(100)
# Out:
#       occurrence_mental  bienestar  estres  sueno  horasfuera enfermo  \
# 2827               10.0        5.0     7.0    5.0         2.0      No
# 284                 2.0        5.0     NaN    NaN         2.0     NaN
# 1563               10.0       10.0     1.0   10.0         0.0      No
# 3259                2.0        9.0     6.0    6.0         3.0      No
# 362                11.0        8.0     3.0    8.0         NaN      No
# 2714                4.0        8.0     5.0    8.0         0.0      No
# 2660                6.0        3.0     9.0    8.0         1.0     Yes
# 1826                8.0        3.0     9.0    4.0        11.0     Yes
# 3216               11.0        9.0     NaN    8.0         1.0      No
# 1410     61.0   Mujer               30648.0
# 2302     41.0   Mujer               34770.0
# 382      53.0   Mujer               29223.0
# 1308      NaN   Mujer                   NaN
# 477      53.0   Mujer               29223.0
# 610      39.0   Mujer               33577.0
# 163      25.0  Hombre               27350.0
# 1051     18.0   Mujer               30648.0
# 1437     36.0  Hombre               29223.0
# 3147     25.0   Mujer               34770.0
# 2524     40.0   Mujer               49196.0
# 2448     40.0   Mujer               49196.0
# 3085     43.0   Mujer               30648.0
# 2973     48.0  Hombre               30648.0
# 758      37.0   Mujer               30648.0
# 1292      NaN   Mujer               27350.0
# 2813     34.0  Hombre               27350.0
# 1415     50.0  Hombre               49196.0
# 2120     44.0  Hombre               34770.0
# 2145     32.0  Hombre               34770.0
# 1012     28.0  Hombre               27350.0
# 567      56.0  Hombre               22844.0
# 2895     46.0   Mujer               30648.0
# 2220     44.0   Mujer               29223.0
# 1946     19.0   Mujer               29223.0
# 1138     43.0   Mujer               27350.0
# 179      35.0  Hombre               30648.0
# 3222     44.0  Hombre               30648.0
# 789      27.0   Mujer               49196.0
# 95       25.0  Hombre               33577.0
# 1391     62.0  Hombre               30648.0
# 1356     35.0   Mujer                   NaN
# 3124     35.0   Mujer               27350.0
# 1063     51.0   Mujer               30648.0
# 2366     47.0   Mujer               30648.0
# 1360     53.0   Mujer               41548.0
# 2864     45.0   Mujer               41548.0
# 124      36.0   Mujer               27877.0
# 107      45.0   Mujer               30648.0
# 849      19.0   Mujer               29223.0
# 662      41.0   Mujer               29223.0
# 1711     22.0   Mujer               27877.0
# 1773     33.0   Mujer               30648.0
# 1799     48.0   Mujer               22529.0
# 564      27.0   Mujer               49196.0
# 1789     40.0   Mujer               33577.0
# 1241     66.0   Mujer               22529.0
# 140      37.0   Mujer               33577.0
# 2554     43.0   Mujer               27877.0
# 2627     35.0   Mujer               30648.0
# 979      23.0  Hombre               49196.0
# 3072     35.0   Mujer               27350.0
# 1185     33.0   Mujer               30648.0
# 805      32.0   Mujer               33577.0
# 1562     46.0   Mujer               27877.0
# 149      50.0  Hombre               34770.0
# 2870      NaN   Mujer                   NaN
# 2539     18.0   Mujer                   NaN
# 792      28.0   Mujer               34770.0
# 2580     57.0   Mujer               27350.0

# %%
for i in BCN_DF["district"]:
    if i = 'Horta-Guinardo': 
        BCN_DF["district_mean_salary"] = '29223'
    elif i = 'Gràcia':
        BCN_DF["district_mean_salary"] = '33577'
    elif i = 'Eixample':
        BCN_DF["district_mean_salary"] = '34770'
    elif i = 'Sant Martí':
        BCN_DF["district_mean_salary"] = '30648'
    elif i = 'Sants-Montjuïc':
        BCN_DF["district_mean_salary"] = '27350'
    elif i = 'Sant Andreu':
        BCN_DF["district_mean_salary"] = '27877'
    elif i = 'Sarria Sant-Gervasi':
        BCN_DF["district_mean_salary"] = '49196'
    elif i = 'Nou Barris':
        BCN_DF["district_mean_salary"] = '22844'
    elif i = 'Les Corts':
        BCN_DF["district_mean_salary"] = '41548'
    elif i = 'Ciutat Vella':
        BCN_DF["district_mean_salary"] = '22529'
    else:
        BCN_DF["district_mean_salary"] = None

# %%
pd.set_option('display.max_rows', None)  # None means show all rows
pd.set_option('display.max_columns', None)

# %%
BCN_DF["age_yrs"].max()
# Out:
# 76.0

# %%
BCN_DF.isna().sum()
# Out:
# occurrence_mental                   68
# bienestar                           75
# estres                             175
# sueno                              158
# horasfuera                         117
# enfermo                            127
# performance                        302
# z_performance                      302
# µgm3                               330
# district                           165
# sec_noise55_day                    490
# hours_greenblue_day                490
# access_greenbluespaces_300mbuff    300
# age_yrs                            176
# gender                              10
# dtype: int64

# %%
BCN_DF["gender"].value_counts()
# Out:
# gender
# Mujer     2363
# Hombre     970
# Otra         5
# Name: count, dtype: int64

# %%
BCN_DF["district"].value_counts()
# Out:
# district
# Sant Martí             681
# Eixample               599
# Gràcia                 513
# Sants-Montjuïc         282
# Sant Andreu            250
# Ciutat Vella           234
# Horta-Guinardo         208
# Sarria Sant-Gervasi    177
# Nou Barris             107
# 16                      67
# Les Corts               65
# Name: count, dtype: int64

# %%
BCN_DF["age_yrs"].value_counts()
# Out:
# age_yrs
# 28.0    161
# 48.0    151
# 19.0    136
# 40.0    124
# 43.0    119
# 36.0    114
# 44.0    113
# 33.0    111
# 31.0    109
# 34.0    105
# 35.0    105
# 39.0     99
# 29.0     93
# 46.0     92
# 18.0     90
# 42.0     88
# 37.0     84
# 45.0     83
# 32.0     76
# 26.0     72
# 24.0     67
# 27.0     63
# 38.0     62
# 50.0     62
# 20.0     62
# 53.0     59
# 25.0     59
# 56.0     58
# 41.0     58
# 49.0     55
# 58.0     52
# 54.0     39
# 23.0     38
# 55.0     34
# 61.0     31
# 22.0     30
# 47.0     28
# 52.0     28
# 51.0     26
# 62.0     26
# 21.0     23
# 63.0     14
# 76.0     14
# 57.0     13
# 75.0     12
# 60.0     11
# 66.0     10
# 30.0     10
# 64.0      3
# Name: count, dtype: int64

# %%
BCN_DF.to_csv("edu_project_IV/data/BCN_DF_clean.csv", index = False)

# %%
import sqlalchemy as alch # bash: conda activate ironhack; python -m pip install --upgrade 'sqlalchemy<2.0'
                                                        # pip install SQLAlchemy
from getpass import getpass
import pandas as pd
import os
password = getpass()
dbName = "BCN_DF"
connectionData=f"mysql+pymysql://root:{password}@localhost/{dbName}"
engine = alch.create_engine(connectionData)
# Out:
# ········

# %%
BCN_DF.to_sql("BCN_DF", if_exists="replace", con=engine, index=False)
# Out:
# 3348

# %%
#SQL Query to look for any patterns in older participants recording more or fewer mental health issues

# %%
query = ''' 
SELECT
    CASE
        WHEN age_yrs BETWEEN 18 AND 25 THEN '18-25'
         WHEN age_yrs BETWEEN 26 AND 35 THEN '26-35'
        WHEN age_yrs BETWEEN 36 AND 55 THEN '36-55'
        WHEN age_yrs BETWEEN 56 AND 76 THEN '56-76'
    END AS age_group,
    AVG(occurrence_mental),
    AVG(bienestar), 
    AVG(estres), 
    AVG(sueno), 
    AVG(horasfuera)
FROM
    BCN_DF
GROUP BY
    age_group
ORDER BY age_group;
'''
pd.read_sql_query(query, engine)
# Out:
#   age_group  AVG(occurrence_mental)  AVG(bienestar)  AVG(estres)  AVG(sueno)  \
# 0      None                6.457831        7.307229     3.733766    6.889610
# 1     18-25                6.376000        7.376258     4.010331    7.145194
# 2     26-35                6.988688        7.067950     4.332176    6.879863
# 3     36-55                6.637340        7.271198     4.384880    6.842141
# 4     56-76                6.585062        7.091286     3.930556    6.787037
#
#    AVG(horasfuera)
# 0         6.333333
# 1         4.592331
# 2         5.187213
# 3         5.319577
# 4         5.349372

# %%
#SQL Query to look for any patterns in men or women recording more or fewer mental health issues

# %%
query = ''' 
SELECT
    gender,
    AVG(occurrence_mental),
    AVG(bienestar), 
    AVG(estres), 
    AVG(sueno),
    AVG(horasfuera)
FROM
    BCN_DF
GROUP BY
    gender;
'''
pd.read_sql_query(query, engine)
# Out:
#    gender  AVG(occurrence_mental)  AVG(bienestar)  AVG(estres)  AVG(sueno)  \
# 0   Mujer                6.687122        7.238425     4.328258    6.892794
# 1  Hombre                6.691903        7.187962     4.072432    6.910464
# 2    None                5.500000        6.600000     3.700000    6.700000
# 3    Otra                3.000000        6.600000     3.800000    7.000000
#
#    AVG(horasfuera)
# 0         5.154352
# 1         5.452444
# 2         3.200000
# 3         0.400000

# %%
#SQL Query to look for patterns in people from different districts reporting more or fewer mental health issues

# %%
query = ''' 
SELECT
    district,
    AVG(occurrence_mental),
    AVG(bienestar), 
    AVG(estres), 
    AVG(sueno),
    AVG(horasfuera)
FROM
    BCN_DF
GROUP BY
    district;
'''
pd.read_sql_query(query, engine)
# Out:
#                district  AVG(occurrence_mental)  AVG(bienestar)  AVG(estres)  \
# 0        Horta-Guinardo                6.384615        6.948454     4.659574
# 1                Gràcia                6.718504        7.287968     4.267490
# 2              Eixample                6.688027        6.959459     4.344291
# 3            Sant Martí                6.703148        7.153846     4.163859
# 4        Sants-Montjuïc                6.953901        7.138298     4.338078
# 5          Ciutat Vella                6.519313        7.519313     4.593750
# 6           Sant Andreu                6.683761        7.512821     3.964602
# 7   Sarria Sant-Gervasi                6.474286        7.520000     3.831325
# 8            Nou Barris                6.887850        6.654206     5.019608
# 9                  None                6.496774        7.464516     3.894366
# 10                   16                6.507463        7.761194     4.181818
# 11            Les Corts                7.125000        7.812500     3.065574
#
#     AVG(sueno)  AVG(horasfuera)
# 0     6.575916         6.062827
# 1     6.916155         5.282435
# 2     6.876501         5.129296
# 3     6.738863         4.450455
# 4     6.524823         5.267399
# 5     7.477876         5.264693
# 6     7.643478         5.504292
# 7     6.927273         5.631429
# 8     6.524272         5.785047
# 9     6.809859         6.677419
# 10    6.676923         4.431818
# 11    7.380952         5.183333

# %%
#Interesting further steps here could be to scrape info or find another database on average income in these neighbourhoods
#Potential socio-economic factors, for example in Nou Barris reporting lower bienestar highest stress, low sueño.

# %%
query = ''' 
SELECT
    district,
    AVG(performance)
FROM
    BCN_DF
GROUP BY
    district;
'''
pd.read_sql_query(query, engine)
# Out:
#                district  AVG(performance)
# 0        Horta-Guinardo         45.257779
# 1                Gràcia         47.460933
# 2              Eixample         47.648896
# 3            Sant Martí         45.931447
# 4        Sants-Montjuïc         50.598583
# 5          Ciutat Vella         47.867348
# 6           Sant Andreu         51.612481
# 7   Sarria Sant-Gervasi         47.237122
# 8            Nou Barris         42.206051
# 9                  None         43.076593
# 10                   16         49.306591
# 11            Les Corts         45.496545
